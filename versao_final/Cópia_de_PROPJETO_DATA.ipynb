# %%
# vscodepets
import pandas as pd
import re
import numpy as np
import requests
from flask import Flask, jsonify, make_response, request
import csv
import sys

def busca_tema():

    url = 'https://newsapi.org/v2/everything?q=bitcoin+blockchain+web3&from=2024-03-10&to=2024-04-03&language=en&sortBy=published&page=1&apiKey=df97b6ec3d3148c2a0f34e552e3f53af'
    r = requests.get(url)

    if r.status_code == 200:

        results = r.json()

    else:
        return print("Problema na requisição.")


    return results
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # vscodepets
# ----> 2 import pandas as pd
#       3 import re
#       4 import numpy as np
#
# File c:\Users\Lucas Guimarães\anaconda3\Lib\site-packages\pandas\__init__.py:46
#      43 # let init-time option registration happen
#      44 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 46 from pandas.core.api import (
#      47     # dtype
#      48     ArrowDtype,
#      49     Int8Dtype,
#      50     Int16Dtype,
#      51     Int32Dtype,
#      52     Int64Dtype,
#      53     UInt8Dtype,
#      54     UInt16Dtype,
#      55     UInt32Dtype,
#      56     UInt64Dtype,
#      57     Float32Dtype,
#      58     Float64Dtype,
#      59     CategoricalDtype,
#      60     PeriodDtype,
#      61     IntervalDtype,
#      62     DatetimeTZDtype,
#      63     StringDtype,
#      64     BooleanDtype,
#      65     # missing
#      66     NA,
#      67     isna,
#      68     isnull,
#      69     notna,
#      70     notnull,
#      71     # indexes
#      72     Index,
#      73     CategoricalIndex,
#      74     RangeIndex,
#      75     MultiIndex,
#      76     IntervalIndex,
#      77     TimedeltaIndex,
#      78     DatetimeIndex,
#      79     PeriodIndex,
#      80     IndexSlice,
#      81     # tseries
#      82     NaT,
#      83     Period,
#      84     period_range,
#      85     Timedelta,
#      86     timedelta_range,
#      87     Timestamp,
#      88     date_range,
#      89     bdate_range,
#      90     Interval,
#      91     interval_range,
#      92     DateOffset,
#      93     # conversion
#      94     to_numeric,
#      95     to_datetime,
#      96     to_timedelta,
#      97     # misc
#      98     Flags,
#      99     Grouper,
#     100     factorize,
#     101     unique,
#     102     value_counts,
#     103     NamedAgg,
#     104     array,
#     105     Categorical,
#     106     set_eng_float_format,
#     107     Series,
#     108     DataFrame,
#     109 )
#     111 from pandas.core.dtypes.dtypes import SparseDtype
#     113 from pandas.tseries.api import infer_freq
#
# File c:\Users\Lucas Guimarães\anaconda3\Lib\site-packages\pandas\core\api.py:28
#      16 from pandas.core.dtypes.missing import (
#      17     isna,
#      18     isnull,
#      19     notna,
#      20     notnull,
#      21 )
#      23 from pandas.core.algorithms import (
#      24     factorize,
#      25     unique,
#      26     value_counts,
#      27 )
# ---> 28 from pandas.core.arrays import Categorical
#      29 from pandas.core.arrays.boolean import BooleanDtype
#      30 from pandas.core.arrays.floating import (
#      31     Float32Dtype,
#      32     Float64Dtype,
#      33 )
#
# File c:\Users\Lucas Guimarães\anaconda3\Lib\site-packages\pandas\core\arrays\__init__.py:9
#       7 from pandas.core.arrays.boolean import BooleanArray
#       8 from pandas.core.arrays.categorical import Categorical
# ----> 9 from pandas.core.arrays.datetimes import DatetimeArray
#      10 from pandas.core.arrays.floating import FloatingArray
#      11 from pandas.core.arrays.integer import IntegerArray
#
# File c:\Users\Lucas Guimarães\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:16
#      12 import warnings
#      14 import numpy as np
# ---> 16 from pandas._libs import (
#      17     lib,
#      18     tslib,
#      19 )
#      20 from pandas._libs.tslibs import (
#      21     BaseOffset,
#      22     NaT,
#    (...)
#      40     tzconversion,
#      41 )
#      42 from pandas._libs.tslibs.dtypes import abbrev_to_npy_unit
#
# File <frozen importlib._bootstrap>:405, in parent(self)
#
# KeyboardInterrupt:

# %%
df = pd.json_normalize(busca_tema()['articles']).head()

# %%
df.head()
# Out:
#                                               author  \
# 0                                     Thomas Claburn
# 1  Cleve Mesidor, Contributor, \n Cleve Mesidor, ...
# 2  Lawrence Wintermeyer, Contributor, \n Lawrence...
# 3                                     cryptonews.com
# 4  Victoria Chynoweth, Contributor, \n Victoria C...
#
#                                                title  \
# 0  We talk to W3C vice chair Robin Berjon about t...
# 1       Next Gen Women At Forefront Of Crypto Policy
# 2  15 Months After FTX, Trust In Web3 Technology ...
# 3  This New $5M Fund Aims to Scale Bitcoin-Aligne...
# 4  Creative Strategies Are Helping Asian VCs Stan...
#
#                                          description  \
# 0  The decentralized web is alive and well despit...
# 1  As Women’s HERstory Month comes to a close, di...
# 2  The surge of institutional interest in digital...
# 3  Core Foundation has announced a $5 million inn...
# 4  Asia is becoming a battleground for startups a...
#
#                                                  url  \
# 0  https://www.theregister.com/2024/03/15/intervi...
# 1  https://www.forbes.com/sites/digital-assets/20...
# 2  https://www.forbes.com/sites/lawrencewintermey...
# 3              https://biztoc.com/x/4ef5dde59e4756ba
# 4  https://www.forbes.com/sites/digital-assets/20...
#
#                                           urlToImage           publishedAt  \
# 0  https://regmedia.co.uk/2023/08/16/shutterstock...  2024-03-15T15:30:09Z
# 1  https://imageio.forbes.com/specials-images/ima...  2024-03-29T15:26:49Z
# 2  https://imageio.forbes.com/specials-images/ima...  2024-03-21T13:40:16Z
# 3     https://c.biztoc.com/p/4ef5dde59e4756ba/s.webp  2024-03-11T01:10:15Z
# 4  https://imageio.forbes.com/specials-images/ima...  2024-03-18T15:17:51Z
#
#                                              content source.id  \
# 0  Interview The InterPlanetary File System (IPFS...      None
# 1  UNITED STATES - JUNE 23: A female member of co...      None
# 2  MANHATTAN, NEW YORK, UNITED STATES - 2021/10/1...      None
# 3  Core Foundation has announced a $5 million inn...      None
# 4  This photo taken on May 27, 2023 shows a woman...      None
#
#        source.name
# 0  Theregister.com
# 1           Forbes
# 2           Forbes
# 3       Biztoc.com
# 4           Forbes

# %%
try:

  pd.read_csv('code.csv')
  print("base ja existe")

except:

  print("base nao existe -- salvando csv")
  df.to_csv('code.csv')
# Out:
# base ja existe

# %%
### nova requisicao

df_newReq = pd.json_normalize(busca_tema()['articles']).head()
df_newReq.head()
# Out:
#                                               author  \
# 0                                     Thomas Claburn
# 1  Cleve Mesidor, Contributor, \n Cleve Mesidor, ...
# 2  Lawrence Wintermeyer, Contributor, \n Lawrence...
# 3                                     cryptonews.com
# 4  Victoria Chynoweth, Contributor, \n Victoria C...
#
#                                                title  \
# 0  We talk to W3C vice chair Robin Berjon about t...
# 1       Next Gen Women At Forefront Of Crypto Policy
# 2  15 Months After FTX, Trust In Web3 Technology ...
# 3  This New $5M Fund Aims to Scale Bitcoin-Aligne...
# 4  Creative Strategies Are Helping Asian VCs Stan...
#
#                                          description  \
# 0  The decentralized web is alive and well despit...
# 1  As Women’s HERstory Month comes to a close, di...
# 2  The surge of institutional interest in digital...
# 3  Core Foundation has announced a $5 million inn...
# 4  Asia is becoming a battleground for startups a...
#
#                                                  url  \
# 0  https://www.theregister.com/2024/03/15/intervi...
# 1  https://www.forbes.com/sites/digital-assets/20...
# 2  https://www.forbes.com/sites/lawrencewintermey...
# 3              https://biztoc.com/x/4ef5dde59e4756ba
# 4  https://www.forbes.com/sites/digital-assets/20...
#
#                                           urlToImage           publishedAt  \
# 0  https://regmedia.co.uk/2023/08/16/shutterstock...  2024-03-15T15:30:09Z
# 1  https://imageio.forbes.com/specials-images/ima...  2024-03-29T15:26:49Z
# 2  https://imageio.forbes.com/specials-images/ima...  2024-03-21T13:40:16Z
# 3     https://c.biztoc.com/p/4ef5dde59e4756ba/s.webp  2024-03-11T01:10:15Z
# 4  https://imageio.forbes.com/specials-images/ima...  2024-03-18T15:17:51Z
#
#                                              content source.id  \
# 0  Interview The InterPlanetary File System (IPFS...      None
# 1  UNITED STATES - JUNE 23: A female member of co...      None
# 2  MANHATTAN, NEW YORK, UNITED STATES - 2021/10/1...      None
# 3  Core Foundation has announced a $5 million inn...      None
# 4  This photo taken on May 27, 2023 shows a woman...      None
#
#        source.name
# 0  Theregister.com
# 1           Forbes
# 2           Forbes
# 3       Biztoc.com
# 4           Forbes

# %%
# df_concat: ira registrar as novas entradas;
df_concat = pd.concat([df_newReq, df]).drop_duplicates(subset=['author', 'title'],
                                           keep=False)

df_concat.head()
# Out:
# Empty DataFrame
# Columns: [author, title, description, url, urlToImage, publishedAt, content, source.id, source.name]
# Index: []

# %%
if df_concat.empty:
  print("Não foram encontrados novos registros")

else:

  df = pd.concat([df, df_concat]) # se há novo registro, "append" na base anterior e sobrescreve o arquivo;
  df.to_csv('code.csv')
# Out:
# Não foram encontrados novos registros

# %%
### TATI

# %%
import pandas as pd
import re
import numpy as np
import requests
from flask import Flask, jsonify, make_response, request
import csv
import sys
import time
from datetime import datetime

def busca_tema():
    url = 'https://newsapi.org/v2/everything?q=bitcoin+blockchain+web3&from=2024-03-10&to=2024-04-03&language=en&sortBy=published&page=1&apiKey=df97b6ec3d3148c2a0f34e552e3f53af'
    r = requests.get(url)

    if r.status_code == 200:
        results = r.json()
    else:
        print("Problema na requisição.")
        results = None

    return results

def atualizar_csv():
    df_novo = pd.json_normalize(busca_tema()['articles'])
    try:
        df_antigo = pd.read_csv('code.csv')
        df_atualizado = pd.concat([df_antigo, df_novo]).drop_duplicates(subset=['publishedAt'], keep='last')
        df_atualizado.to_csv('code.csv', index=False)
        print(f"Arquivo CSV atualizado com sucesso em {datetime.now()}.")
    except FileNotFoundError:
        df_novo.to_csv('code.csv', index=False)
        print(f"Arquivo CSV criado com sucesso em {datetime.now()}.")


while True:
    atualizar_csv()
    time.sleep(30)  # Espera 1 hora (3600 segundos) antes de verificar novamente
# Out:
# Arquivo CSV criado com sucesso em 2024-04-04 00:47:30.542401.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-21b61ffd399c> in <cell line: 35>()
#      35 while True:
#      36     atualizar_csv()
# ---> 37     time.sleep(30)  # Espera 1 hora (3600 segundos) antes de verificar novamente
#
# KeyboardInterrupt:

# %%
df = pd.read_csv("code.csv")

# %%
df['ano'] = df.publishedAt.apply(lambda x: x.split('-')[0])
df['mes'] = df.publishedAt.apply(lambda x: x.split('-')[1])
df['dia'] = df.publishedAt.apply(lambda x: x.split('-')[2][:2])

# %%
df.groupby('ano').count()[['title']]
# Out:
#       title
# ano
# 1970      1
# 2024     99

# %%
df.groupby(['ano', 'mes']).count()[['title']]
# Out:
#           title
# ano  mes
# 1970 01       1
# 2024 03      76
#      04      23

# %%
df.groupby(['ano', 'mes', 'dia']).count()[['title']]
# Out:
#               title
# ano  mes dia
# 1970 01  01       1
# 2024 03  10       2
#          11       5
#          12       5
#          13       6
#          14       9
#          15       5
#          16       2
#          17       1
#          18       2
#          19       2
#          20       6
#          21       6
#          22       5
#          23       2
#          25       4
#          26       2
#          27       1
#          28       4
#          29       4
#          30       1
#          31       2
#      04  01       4
#          02      12
#          03       7

# %%
#     - 4.2 - Quantidade de notícias por fonte e autor;

noticias_por_fonte_autor = df.groupby(['source.name', 'author']).size().reset_index(name='Quantidade')
noticias_por_fonte_autor   


# 4.3 - Quantidade de aparições das 3 palavras-chave por ano, mês e dia de publicação definidas no item 2

palavras_chave = ['bitcoin', 'blockchain', 'web3']
for palavra in palavras_chave:
    df[palavra] = df['title'].str.count(palavra, flags=re.IGNORECASE)

aparicoes_palavras_chave = df.groupby(['ano', 'mes', 'dia'])[palavras_chave].sum().reset_index()

aparicoes_palavras_chave

# %%
# Salvando as transformações em arquivo csv
noticias_por_data.to_csv("noticias_por_data.csv",sep=",")
noticias_por_fonte_autor.to_csv("noticias_por_fonte_autor.csv",sep=",",index=False)
aparicoes_palavras_chave.to_csv("aparicoes_palavras_chave.csv",sep=",",index=False)
